# %% [markdown]
# # Baseline GARP Backtest
#
# Runs the open GARP-like multifactor framework on synthetic point-in-time-safe fixtures. Replace providers only when the data source supplies historical `as_of_date` / filing dates.

# %%
from stockresearchmarket.garp.backtest import run_garp_backtest

result = run_garp_backtest("001_baseline_garp", provider="synthetic", years=10)
result.output_dir
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from stockresearchmarket.garp.backtest import run_garp_backtest
#       2
#       3 result = run_garp_backtest("001_baseline_garp", provider="synthetic", years=10)
#       4 result.output_dir
#
# ModuleNotFoundError: No module named 'stockresearchmarket'

# %%
result.metrics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 result.metrics
#
# NameError: name 'result' is not defined

# %%
result.holdings.tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result.holdings.tail(20)
#
# NameError: name 'result' is not defined

# %%
result.data_availability.drop_duplicates(["category", "factor", "status"]).head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result.data_availability.drop_duplicates(["category", "factor", "status"]).head(30)
#
# NameError: name 'result' is not defined
